# %% [markdown]
# ## 蒙特卡洛搜索树

# %%
# 环境配置
# %cd /playground/sgd_deep_learning/sgd_rl/go
import sys
sys.path.append('./python')
# Out:
# /playground/sgd_deep_learning/sgd_rl

# %%
from dlgo import goboard_fast as goboard
from dlgo import gotypes
from dlgo import mcts
from dlgo.utils import print_board, print_move, point_from_coords

# %%
def capture_diff(game_state):
    black_stones = 0
    white_stones = 0
    for r in range(1, game_state.board.num_rows + 1):
        for c in range(1, game_state.board.num_cols + 1):
            p = gotypes.Point(r, c)
            color = game_state.board.get(p)
            if color == gotypes.Player.black:
                black_stones += 1
            elif color == gotypes.Player.white:
                white_stones += 1
    diff = black_stones - white_stones
    if game_state.next_player == gotypes.Player.black:
        return diff
    return -1 * diff

# %%
BOARD_SIZE = 5
game = goboard.GameState.new_game(BOARD_SIZE)
bot = mcts.MCTSAgent(500, temperature=1.4)

while not game.is_over():
    print_board(game.board)
    if game.next_player == gotypes.Player.black:
        human_move = input('输入落子[A1-]:')
        point = point_from_coords(human_move.strip())
        move = goboard.Move.play(point)
    else:
        move = bot.select_move(game)
    print_move(game.next_player, move)
    game = game.apply_move(move)
# Out:
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  .  .  .  .
#  2  .  .  .  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black B2
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  .  .  .  .
#  2  .  x  .  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 3, c 3) - 0.725 (40)
# (r 2, c 1) - 0.686 (35)
# (r 4, c 4) - 0.633 (30)
# (r 4, c 3) - 0.577 (26)
# (r 5, c 4) - 0.565 (23)
# (r 4, c 2) - 0.522 (23)
# (r 3, c 1) - 0.522 (23)
# (r 4, c 5) - 0.500 (22)
# (r 1, c 3) - 0.500 (22)
# (r 3, c 4) - 0.500 (22)
# Select move (r 3, c 3) with win pct 0.725
# Player.white C3
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  .  o  .  .
#  2  .  x  .  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black C2
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  .  o  .  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 3, c 2) - 0.692 (39)
# (r 3, c 4) - 0.657 (35)
# (r 4, c 2) - 0.593 (27)
# (r 4, c 3) - 0.577 (26)
# (r 4, c 4) - 0.560 (25)
# (r 1, c 2) - 0.542 (24)
# (r 1, c 4) - 0.522 (23)
# (r 4, c 1) - 0.522 (23)
# (r 1, c 5) - 0.500 (22)
# (r 3, c 1) - 0.500 (22)
# Select move (r 3, c 2) with win pct 0.692
# Player.white B3
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  o  o  .  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black D3
#  5  .  .  .  .  .
#  4  .  .  .  .  .
#  3  .  o  o  x  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 4, c 2) - 0.605 (43)
# (r 1, c 3) - 0.529 (34)
# (r 4, c 1) - 0.529 (34)
# (r 5, c 4) - 0.500 (30)
# (r 2, c 5) - 0.483 (29)
# (r 4, c 5) - 0.464 (28)
# (r 5, c 2) - 0.444 (27)
# (r 1, c 4) - 0.444 (27)
# (r 4, c 4) - 0.440 (25)
# (r 2, c 1) - 0.417 (24)
# Select move (r 4, c 2) with win pct 0.605
# Player.white B4
#  5  .  .  .  .  .
#  4  .  o  .  .  .
#  3  .  o  o  x  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black C4
#  5  .  .  .  .  .
#  4  .  o  x  .  .
#  3  .  o  o  x  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 4, c 4) - 0.617 (47)
# (r 3, c 1) - 0.541 (37)
# (r 2, c 1) - 0.515 (33)
# (r 2, c 4) - 0.464 (28)
# (r 5, c 3) - 0.464 (28)
# pass - 0.464 (28)
# (r 4, c 1) - 0.444 (27)
# (r 5, c 2) - 0.423 (26)
# (r 5, c 5) - 0.423 (26)
# (r 4, c 5) - 0.417 (24)
# Select move (r 4, c 4) with win pct 0.617
# Player.white D4
#  5  .  .  .  .  .
#  4  .  o  x  o  .
#  3  .  o  o  x  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black C5
#  5  .  .  x  .  .
#  4  .  o  x  o  .
#  3  .  o  o  x  .
#  2  .  x  x  .  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 2, c 4) - 0.768 (69)
# (r 5, c 2) - 0.659 (41)
# (r 3, c 5) - 0.588 (34)
# (r 2, c 1) - 0.588 (34)
# (r 5, c 4) - 0.576 (33)
# (r 3, c 1) - 0.562 (32)
# (r 2, c 5) - 0.548 (31)
# (r 1, c 1) - 0.519 (27)
# (r 4, c 1) - 0.519 (27)
# (r 4, c 5) - 0.500 (26)
# Select move (r 2, c 4) with win pct 0.768
# Player.white D2
#  5  .  .  x  .  .
#  4  .  o  x  o  .
#  3  .  o  o  x  .
#  2  .  x  x  o  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black E4
#  5  .  .  x  .  .
#  4  .  o  x  o  x
#  3  .  o  o  x  .
#  2  .  x  x  o  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 3, c 5) - 0.806 (62)
# (r 1, c 4) - 0.707 (41)
# pass - 0.667 (36)
# (r 5, c 2) - 0.647 (34)
# (r 4, c 1) - 0.636 (33)
# (r 5, c 1) - 0.625 (32)
# (r 1, c 3) - 0.625 (32)
# (r 2, c 1) - 0.625 (32)
# (r 5, c 5) - 0.613 (31)
# (r 2, c 5) - 0.607 (28)
# Select move (r 3, c 5) with win pct 0.806
# Player.white E3
#  5  .  .  x  .  .
#  4  .  o  x  o  x
#  3  .  o  o  .  o
#  2  .  x  x  o  .
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black E2
#  5  .  .  x  .  .
#  4  .  o  x  o  x
#  3  .  o  o  .  o
#  2  .  x  x  o  x
#  1  .  .  .  .  .
#     A  B  C  D  E
# (r 3, c 4) - 0.932 (59)
# (r 2, c 1) - 0.841 (44)
# (r 1, c 5) - 0.811 (37)
# (r 1, c 4) - 0.811 (37)
# (r 5, c 2) - 0.806 (36)
# (r 1, c 3) - 0.806 (36)
# (r 4, c 1) - 0.806 (36)
# (r 5, c 5) - 0.778 (36)
# (r 1, c 2) - 0.771 (35)
# (r 5, c 4) - 0.750 (32)
# Select move (r 3, c 4) with win pct 0.932
# Player.white D3
#  5  .  .  x  .  .
#  4  .  o  x  o  x
#  3  .  o  o  o  o
#  2  .  x  x  o  x
#  1  .  .  .  .  .
#     A  B  C  D  E
# Player.black D1
#  5  .  .  x  .  .
#  4  .  o  x  o  x
#  3  .  o  o  o  o
#  2  .  x  x  o  x
#  1  .  .  .  x  .
#     A  B  C  D  E
# (r 5, c 4) - 0.940 (50)
# (r 5, c 2) - 0.940 (50)
# (r 1, c 3) - 0.918 (49)
# pass - 0.911 (45)
# (r 5, c 1) - 0.911 (45)
# (r 4, c 1) - 0.911 (45)
# (r 1, c 2) - 0.911 (45)
# (r 3, c 1) - 0.868 (38)
# (r 1, c 5) - 0.868 (38)
# (r 1, c 1) - 0.842 (38)
# Select move (r 5, c 4) with win pct 0.940
# Player.white D5
#  5  .  .  x  o  .
#  4  .  o  x  o  x
#  3  .  o  o  o  o
#  2  .  x  x  o  x
#  1  .  .  .  x  .
#     A  B  C  D  E
# Player.black A3
#  5  .  .  x  o  .
#  4  .  o  x  o  x
#  3  x  o  o  o  o
#  2  .  x  x  o  x
#  1  .  .  .  x  .
#     A  B  C  D  E
# (r 1, c 5) - 0.929 (56)
# (r 4, c 1) - 0.929 (56)
# (r 2, c 1) - 0.923 (52)
# (r 1, c 3) - 0.923 (52)
# (r 5, c 2) - 0.923 (52)
# (r 1, c 1) - 0.898 (49)
# pass - 0.898 (49)
# (r 1, c 2) - 0.891 (46)
# (r 5, c 1) - 0.891 (46)
# (r 5, c 5) - 0.800 (35)
# Select move (r 1, c 5) with win pct 0.929
# Player.white E1
#  5  .  .  x  o  .
#  4  .  o  x  o  x
#  3  x  o  o  o  o
#  2  .  x  x  o  .
#  1  .  .  .  x  o
#     A  B  C  D  E
# Player.black A4
#  5  .  .  x  o  .
#  4  x  o  x  o  x
#  3  x  o  o  o  o
#  2  .  x  x  o  .
#  1  .  .  .  x  o
#     A  B  C  D  E
# (r 5, c 2) - 0.913 (69)
# (r 2, c 1) - 0.885 (61)
# (r 1, c 2) - 0.885 (61)
# (r 5, c 1) - 0.860 (57)
# pass - 0.855 (55)
# (r 1, c 3) - 0.849 (53)
# (r 5, c 5) - 0.843 (51)
# (r 1, c 1) - 0.824 (51)
# (r 2, c 5) - 0.743 (35)
# resign - 0.000 (7)
# Select move (r 5, c 2) with win pct 0.913
# Player.white B5
#  5  .  o  .  o  .
#  4  x  o  .  o  x
#  3  x  o  o  o  o
#  2  .  x  x  o  .
#  1  .  .  .  x  o
#     A  B  C  D  E
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 9
#       7 if game.next_player == gotypes.Player.black:
#       8     human_move = input('输入落子[A1-]:')
# ----> 9     point = point_from_coords(human_move.strip())
#      10     move = goboard.Move.play(point)
#      11 else:
#
# File /playground/sgd_deep_learning/sgd_rl/./python/dlgo/utils.py:33, in point_from_coords(coords)
#      32 def point_from_coords(coords):
# ---> 33     col = COLS.index(coords[0]) + 1
#      34     row = int(coords[1:])
#      35     return gotypes.Point(row=row, col=col)
#
# IndexError: string index out of range
