# %% [markdown]
# # policy gradient (part1: 对局数据收集)
#
#     agent1 and agent2 are identical
#     combine their experiences for training (从两个方便收集到的数据一块训练)

# %%
# 环境配置
# %cd /playground/sgd_deep_learning/sgd_rl/go
import sys
sys.path.append('./python')
# Out:
# /playground/sgd_deep_learning/sgd_rl

# %%
import os
import time
import datetime
import torch
from collections import namedtuple

from dlgo import agent
from dlgo import scoring
from dlgo import rl
from dlgo.goboard_fast import GameState, Player, Point

from dlgo.encoders import get_encoder_by_name
from dlgo.networks import cnn_small, resnet18

# %% [markdown]
# ### 脚本输入参数设定

# %%
# 数据 模型存放目录
data_home_path = 'data/pg/'
if not os.path.exists(data_home_path):
    os.makedirs(data_home_path)

# 脚本输入参数 
class args:
    board_size = 9 # 缩小计算量, 保证算法的验证速度
    num_games = 100 # 每轮迭代只收集10games的数据
    learning_agent = data_home_path + 'agent_checkpoint.pth'
    experience_out = data_home_path + 'experience.pth'
    
print(os.path.exists(args.learning_agent))

# 全局变量
global BOARD_SIZE
BOARD_SIZE = args.board_size

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# False
# device: cuda

# %% [markdown]
# ### helper functions

# %%
COLS = 'ABCDEFGHJKLMNOPQRST'
STONE_TO_CHAR = {
    None: '.',
    Player.black: 'x',
    Player.white: 'o',
}

def avg(items):
    if not items:
        return 0.0
    return sum(items) / float(len(items))


def print_board(board):
    for row in range(BOARD_SIZE, 0, -1):
        line = []
        for col in range(1, BOARD_SIZE + 1):
            stone = board.get(Point(row=row, col=col))
            line.append(STONE_TO_CHAR[stone])
        print('%2d %s' % (row, ''.join(line)))
    print('   ' + COLS[:BOARD_SIZE])


class GameRecord(namedtuple('GameRecord', 'moves winner margin')):
    pass

def name(player):
    if player == Player.black:
        return 'B'
    return 'W'

# %% [markdown]
# ### 模拟对局

# %%
def simulate_game(black_player, white_player):
    moves = []
    game = GameState.new_game(BOARD_SIZE)
    agents = {
        Player.black: black_player,
        Player.white: white_player,
    }
    while not game.is_over():
        next_move = agents[game.next_player].select_move(game)
        moves.append(next_move)
        game = game.apply_move(next_move)

    print_board(game.board)
    game_result = scoring.compute_game_result(game)
    print(game_result)

    # nametuple todo moves作用？margin作用？
    return GameRecord(
        moves=moves,
        winner=game_result.winner,
        margin=game_result.winning_margin,
    )

# %% [markdown]
# ### main loop of self_play

# %%
def main_loop():
    agent_filename = args.learning_agent
    experience_filename = args.experience_out
    num_games = args.num_games

    # init agent object
    encoder_name = 'sevenplane'
    model = cnn_small(input_channel_num=7, board_size=BOARD_SIZE) 

    agent1, agent2 = None, None
    
    if not os.path.exists(agent_filename): # check_point不存在
        encoder = get_encoder_by_name(name=encoder_name, board_size=BOARD_SIZE)
        agent1 = agent.load_policy_agent(model=model, encoder=encoder, device=device)
        agent2 = agent.load_policy_agent(model=model, encoder=encoder, device=device)
    else: 
        # 指向同一个model没啥问题吧, 变量重新初始化了一遍
        agent1 = agent.load_policy_agent(model=model, save_path=agent_filename, device=device)
        agent2 = agent.load_policy_agent(model=model, save_path=agent_filename, device=device)
    
    assert (agent1 is not None) and (agent2 is not None)

    collector1 = rl.ExperienceCollector()
    collector2 = rl.ExperienceCollector()
    agent1.set_collector(collector1)
    agent2.set_collector(collector2)
    #######################################################################
    t1 = time.time()

    for i in range(args.num_games):
        print('Simulating game %d/%d...' % (i + 1, args.num_games))
        collector1.begin_episode() # 开始记录， 不是agent负责
        collector2.begin_episode()

        game_record = simulate_game(agent1, agent2) # pg只用了winner变量
        if game_record.winner == Player.black:
            collector1.complete_episode(reward=1)
            collector2.complete_episode(reward=-1)
        else:
            collector2.complete_episode(reward=1)
            collector1.complete_episode(reward=-1)

    print("simulatinon of {} games , cost_time:{:.3f}s.".format(args.num_games, time.time()-t1))

    experience = rl.combine_experience([collector1, collector2]) # 整合所有训练数据
    # with h5py.File(experience_filename, 'w') as experience_outf:
    experience.serialize(experience_filename) # 序列化存储
    
    print("collect {} samples".format(len(experience)))
    
main_loop()
# Out:
# Simulating game 1/100...
#  9 .o.o.oo.o
#  8 ooooooooo
#  7 ooooo.o.o
#  6 oo.oooooo
#  5 oooooo.oo
#  4 .ooooooo.
#  3 oo.ooo.oo
#  2 ooo.ooooo
#  1 .oooooooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 2/100...
#  9 xxxx.xxx.
#  8 xxxxxxxxx
#  7 .xxooxxxx
#  6 xxoooxxx.
#  5 xoo.oxxxx
#  4 o.ooxxxxx
#  3 oooxxxx.x
#  2 oooxxxxxx
#  1 xxxxx.xx.
#    ABCDEFGHJ
# B+35.5
# Simulating game 3/100...
#  9 xxxxooo.o
#  8 xx.xxoooo
#  7 xxx.xoooo
#  6 xxxxxoo.o
#  5 x.xxxoooo
#  4 xxxxxoooo
#  3 xxxxxooo.
#  2 .x.xxo.oo
#  1 xxxxooooo
#    ABCDEFGHJ
# W+2.5
# Simulating game 4/100...
#  9 xxxxoo.o.
#  8 xx.xooooo
#  7 .xxxxxxxo
#  6 xxxxxxxxx
#  5 x.x.xx.xx
#  4 xxxxxxxxx
#  3 xxxxxxx.x
#  2 xxxxxxxxx
#  1 x.xx.x.x.
#    ABCDEFGHJ
# B+51.5
# Simulating game 5/100...
#  9 xxxxx.xx.
#  8 xx.xxxxxx
#  7 xxxxxx.xx
#  6 .xxxxxxx.
#  5 xx.xxx.xx
#  4 x.xxxxxx.
#  3 xxxxxxxxx
#  2 xxxx.xxxx
#  1 .x.xxxxx.
#    ABCDEFGHJ
# B+73.5
# Simulating game 6/100...
#  9 ooooooox.
#  8 oo.ooooxx
#  7 ooooo.oxx
#  6 o.oooooxx
#  5 ooxooooox
#  4 oxxoxxxxx
#  3 xxxxxx.xx
#  2 xxxxxxxxx
#  1 x.xx.xxx.
#    ABCDEFGHJ
# W+0.5
# Simulating game 7/100...
#  9 oo.ooxxxx
#  8 .oooooxx.
#  7 oooooxxxx
#  6 oo.ooxx.x
#  5 oooooxxxx
#  4 oo.oxxxxx
#  3 ooooxxxxx
#  2 o.oox.x.x
#  1 ooxxxxxxx
#    ABCDEFGHJ
# W+6.5
# Simulating game 8/100...
#  9 o.ooooo.o
#  8 ooo.o.ooo
#  7 ooooooooo
#  6 oo.oooooo
#  5 oooo.ooo.
#  4 xxooooooo
#  3 xooooooxx
#  2 xxxoxooxx
#  1 x.xxxxxx.
#    ABCDEFGHJ
# W+48.5
# Simulating game 9/100...
#  9 xx.xxxxoo
#  8 .xxxoooo.
#  7 xxxooo.oo
#  6 ooxoxxoo.
#  5 ooxxxxooo
#  4 oooxxoooo
#  3 o.ooo.oo.
#  2 ooooooooo
#  1 ooooo.oo.
#    ABCDEFGHJ
# W+42.5
# Simulating game 10/100...
#  9 ooo.oo.o.
#  8 ooooooooo
#  7 xxoxo.ooo
#  6 .xxxooo.o
#  5 xxxxxoooo
#  4 xxx.xoo.o
#  3 xxxxxoooo
#  2 xxx.xxxxo
#  1 xxxxx.xxx
#    ABCDEFGHJ
# W+10.5
# Simulating game 11/100...
#  9 xxxxxxxxx
#  8 xxx.xooox
#  7 xxxxxxooo
#  6 oxx.xoooo
#  5 ooxxxooxx
#  4 ooxooox.x
#  3 .oooooxxx
#  2 oooo.oxxx
#  1 oo.ooox.x
#    ABCDEFGHJ
# W+2.5
# Simulating game 12/100...
#  9 ooooooxxx
#  8 o.ooxxx.x
#  7 oooox.xxx
#  6 ooooxxxxx
#  5 oxxxxxxx.
#  4 oooxooxxx
#  3 oxxxxooxx
#  2 ooooxooox
#  1 .ooooooxx
#    ABCDEFGHJ
# W+8.5
# Simulating game 13/100...
#  9 o.o.ooooo
#  8 oooooooo.
#  7 oooooo.oo
#  6 oo.oooooo
#  5 oooooxxoo
#  4 ooo.oxxox
#  3 .oooxxxxx
#  2 ooxx.xxxx
#  1 ooxxxx.xx
#    ABCDEFGHJ
# W+40.5
# Simulating game 14/100...
#  9 ooooo.ooo
#  8 o.ooooo.o
#  7 oooo.o.oo
#  6 ooo.ooooo
#  5 .oooooooo
#  4 ooooooooo
#  3 oooooo.o.
#  2 ooooooooo
#  1 .oo.o.ooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 15/100...
#  9 xxxxx.xx.
#  8 x.x.xxxxx
#  7 xxxxxxxxx
#  6 xxx.xxooo
#  5 oooxxoooo
#  4 oooxxoooo
#  3 o.ox.xo.o
#  2 ooxxxxooo
#  1 .oxxxooo.
#    ABCDEFGHJ
# B+5.5
# Simulating game 16/100...
#  9 x.x.xx.x.
#  8 xxxxxxxxx
#  7 .x.xxooxx
#  6 xxxxooooo
#  5 xxoo.o.oo
#  4 .xooooooo
#  3 xxoo.ooo.
#  2 ooooooooo
#  1 .ooooo.oo
#    ABCDEFGHJ
# W+18.5
# Simulating game 17/100...
#  9 .ooo.oxxx
#  8 oo.oooxx.
#  7 oooooooxx
#  6 o.oo.oxx.
#  5 oooooooxx
#  4 oooooooox
#  3 oooooxxxx
#  2 .oooxx.x.
#  1 oooxxxxxx
#    ABCDEFGHJ
# W+30.5
# Simulating game 18/100...
#  9 .oooooooo
#  8 ooooo.ooo
#  7 ooooooo.o
#  6 .oooo.ooo
#  5 ooo.ooo.o
#  4 o.ooooooo
#  3 ooooo.ooo
#  2 ooooooo.o
#  1 .oo.ooooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 19/100...
#  9 oo.oooooo
#  8 oooooxxxo
#  7 ooooxxxxo
#  6 .ooox.xxx
#  5 ooxxxxxx.
#  4 oox.xxxxx
#  3 oxxxx.xx.
#  2 x.x.xxxxx
#  1 xxxxx.xxx
#    ABCDEFGHJ
# B+15.5
# Simulating game 20/100...
#  9 xooo.oo.o
#  8 xxooooooo
#  7 .xxoxooo.
#  6 xxxxxoxoo
#  5 xxxxxxxoo
#  4 x.x.xxo.o
#  3 xxxxxoooo
#  2 xxxxxxooo
#  1 x.xxoooo.
#    ABCDEFGHJ
# W+6.5
# Simulating game 21/100...
#  9 oxxx.xxxx
#  8 oooxxx.xx
#  7 oooxxxxx.
#  6 xo.oxxoxx
#  5 xoooooooo
#  4 xooooooo.
#  3 xxooxxooo
#  2 xxxxxxxxo
#  1 x.x.xx.xx
#    ABCDEFGHJ
# B+7.5
# Simulating game 22/100...
#  9 x.xxxxxx.
#  8 xxxxx.xxx
#  7 xxxxxxx.x
#  6 xxxxx.xxx
#  5 x.x.xxx.x
#  4 xxxxxxxxx
#  3 xx.xxx.xx
#  2 xxxxxxxx.
#  1 .xx.x.xxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 23/100...
#  9 xx.x.xxxx
#  8 xxxxxx.xo
#  7 .x.x.xxxo
#  6 xxxxxxxxo
#  5 xx.xxxxoo
#  4 xxxx.xxo.
#  3 .xxxxxooo
#  2 xxx.xxooo
#  1 .xxxxxo.o
#    ABCDEFGHJ
# B+41.5
# Simulating game 24/100...
#  9 ooooooooo
#  8 o.ooooooo
#  7 oooo.o.o.
#  6 o.ooooooo
#  5 oooo.oooo
#  4 .oo.ooo.o
#  3 ooooooooo
#  2 ooo.ooooo
#  1 .ooooooo.
#    ABCDEFGHJ
# W+88.5
# Simulating game 25/100...
#  9 xxxx.xxoo
#  8 xx.xxxooo
#  7 xxxxxxxoo
#  6 xxxooxxoo
#  5 x.xo.oo.o
#  4 xxooooooo
#  3 xxxo.oooo
#  2 xxxooooo.
#  1 xxooo.ooo
#    ABCDEFGHJ
# W+12.5
# Simulating game 26/100...
#  9 .o.ooxxx.
#  8 ooooox.xx
#  7 .ooooxxox
#  6 oo.oooxox
#  5 ooooooooo
#  4 oo.oooooo
#  3 oooo.o.o.
#  2 ooooooooo
#  1 o.oo.o.o.
#    ABCDEFGHJ
# W+62.5
# Simulating game 27/100...
#  9 x.xoooooo
#  8 xxxo.o.o.
#  7 .xxoooooo
#  6 xxooxo.o.
#  5 xxxoxoooo
#  4 xxxxxoxoo
#  3 xx.xxxxoo
#  2 .xxx.xxoo
#  1 xx.xxxxxx
#    ABCDEFGHJ
# B+1.5
# Simulating game 28/100...
#  9 .xxxxxxxx
#  8 xxxxxxx.x
#  7 xxx.xooxx
#  6 .xxxxxoxx
#  5 xxxxoooox
#  4 xxxxoo.oo
#  3 ooxoooooo
#  2 ooo.ooo.o
#  1 o.ooooooo
#    ABCDEFGHJ
# W+2.5
# Simulating game 29/100...
#  9 xxxxxoooo
#  8 .x.xo.ooo
#  7 xxxxoooo.
#  6 x.xxxxooo
#  5 xxxxxxxo.
#  4 xxx.xxooo
#  3 x.xxxxxoo
#  2 xxxx.xxo.
#  1 .xxxxxooo
#    ABCDEFGHJ
# B+15.5
# Simulating game 30/100...
#  9 ooxx.xxxx
#  8 oxxxxxxxx
#  7 ooxxxxxx.
#  6 .ooooxxxx
#  5 oooox.xxx
#  4 oo.oxxxxx
#  3 ooooxxxxx
#  2 .oooxxxx.
#  1 oo.oxx.xx
#    ABCDEFGHJ
# B+13.5
# Simulating game 31/100...
#  9 xx.x.xxxx
#  8 oxxxxxx.x
#  7 oooxxxxxx
#  6 .oxxxxx.x
#  5 ooxxxoxxx
#  4 oooxxoxox
#  3 o.ooooooo
#  2 ooo.ooooo
#  1 ooooo.oo.
#    ABCDEFGHJ
# W+8.5
# Simulating game 32/100...
#  9 .x.xx.xx.
#  8 xxxxxxxxx
#  7 .xx.xxxxx
#  6 xxxxxooxx
#  5 ooooooooo
#  4 oooo.oooo
#  3 .oooooooo
#  2 oooooo.oo
#  1 .o.oooooo
#    ABCDEFGHJ
# W+20.5
# Simulating game 33/100...
#  9 .ooo.oox.
#  8 ooooooxxx
#  7 o.ooxxxxx
#  6 ooooxx.xx
#  5 xxooxxx.x
#  4 xooxx.xxx
#  3 xxxxxxxxx
#  2 .xxxxxxxx
#  1 xx.x.xx.x
#    ABCDEFGHJ
# B+23.5
# Simulating game 34/100...
#  9 x.xooooo.
#  8 xxxo.o.oo
#  7 x.xooooo.
#  6 xxxooo.oo
#  5 x.xxooo.o
#  4 xxxxooooo
#  3 xxx.xo.o.
#  2 xxxxxoooo
#  1 x.xxxooo.
#    ABCDEFGHJ
# W+18.5
# Simulating game 35/100...
#  9 xxxxxxx.x
#  8 x.xxx.xxx
#  7 xxx.xxxxx
#  6 xxxxx.x.x
#  5 .xxxxxxxx
#  4 xx.xx.xx.
#  3 xxxxxx.xx
#  2 xx.xxxxxx
#  1 xxxxx.x.x
#    ABCDEFGHJ
# B+73.5
# Simulating game 36/100...
#  9 .oo.oooo.
#  8 ooooooooo
#  7 .oo.ooooo
#  6 oooooo.oo
#  5 xooxooooo
#  4 xxxxooo.o
#  3 x.xoooooo
#  2 xxxo.oooo
#  1 .xxxoo.oo
#    ABCDEFGHJ
# W+56.5
# Simulating game 37/100...
#  9 o.ooooxx.
#  8 ooooxxxxx
#  7 ooooxoxxx
#  6 o.oxxooxo
#  5 oooxxxooo
#  4 oooxx.xoo
#  3 o.ooxxxxo
#  2 ooo.ooooo
#  1 .oooo.o.o
#    ABCDEFGHJ
# W+36.5
# Simulating game 38/100...
#  9 ooooooooo
#  8 ooo.oo.oo
#  7 o.ooooooo
#  6 ooooxoo.o
#  5 ooooxxooo
#  4 xxoxxxooo
#  3 xxxx.xooo
#  2 xx.xxxooo
#  1 .xxxxxxo.
#    ABCDEFGHJ
# W+34.5
# Simulating game 39/100...
#  9 ooooxxxxx
#  8 oo.oxxx.x
#  7 ooooooxxx
#  6 oooooxxx.
#  5 oooooxxxx
#  4 ooxxxxxx.
#  3 ooxoxx.xx
#  2 .ooooxxx.
#  1 ooo.ox.xx
#    ABCDEFGHJ
# W+4.5
# Simulating game 40/100...
#  9 x.x.xxx.x
#  8 xxxxxxxxx
#  7 xxxxx.xx.
#  6 xooxxxxxx
#  5 oooox.xox
#  4 oooxxxooo
#  3 o.ooooooo
#  2 oooooo.oo
#  1 oo.oooooo
#    ABCDEFGHJ
# W+6.5
# Simulating game 41/100...
#  9 x.xx.xxxx
#  8 xxxxxxxoo
#  7 xxxxoxxxo
#  6 x.xoooooo
#  5 xxxxooooo
#  4 x.xxxooo.
#  3 xxxxxxxoo
#  2 xxxxooooo
#  1 xx.xo.o.o
#    ABCDEFGHJ
# B+11.5
# Simulating game 42/100...
#  9 .xxxoooo.
#  8 xxxxxoooo
#  7 x.xxxxooo
#  6 xx.xxxooo
#  5 xxxxxxooo
#  4 .xx.xxo.o
#  3 xxxxxxooo
#  2 xxx.xxxxo
#  1 .xxxxxxxx
#    ABCDEFGHJ
# B+23.5
# Simulating game 43/100...
#  9 xxxxxx.x.
#  8 x.xooxxxx
#  7 xxxooxxxx
#  6 xxoooxxxo
#  5 xxxo.oxoo
#  4 xxooooooo
#  3 x.xoooo.o
#  2 xxxxo.ooo
#  1 xx.xxooo.
#    ABCDEFGHJ
# B+3.5
# Simulating game 44/100...
#  9 xxx.xxxxx
#  8 .xxxxxx.x
#  7 xxxxxxxxx
#  6 xxx.xxxxx
#  5 x.xxxx.x.
#  4 xxxxxxxxx
#  3 xxxx.xxxx
#  2 x.x.xxx.x
#  1 xxxxxxxxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 45/100...
#  9 ooooo.o.o
#  8 oo.oooooo
#  7 oooooooo.
#  6 ooooooooo
#  5 oooooo.oo
#  4 ooo.ooo.o
#  3 ooooooooo
#  2 oo.ooo.oo
#  1 ooooooooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 46/100...
#  9 .xxooooo.
#  8 xxxooo.oo
#  7 xxxooxooo
#  6 .xxooxoo.
#  5 xx.xxxxoo
#  4 .xxx.xxox
#  3 xxxxxxxxx
#  2 xxxxxx.xx
#  1 xxx.xxxx.
#    ABCDEFGHJ
# B+23.5
# Simulating game 47/100...
#  9 .o.ooxxxx
#  8 oooooooox
#  7 o.o.oo.ox
#  6 oooooooxx
#  5 xoxo.oxxx
#  4 xxxxooox.
#  3 x.xxxxoxx
#  2 xxxx.xxxx
#  1 x.xxxxx.x
#    ABCDEFGHJ
# B+1.5
# Simulating game 48/100...
#  9 ooooo.o.o
#  8 ooxxooooo
#  7 oxxxxooox
#  6 ooooxxxxx
#  5 .o.oxxx.x
#  4 oooxxxxxx
#  3 o.ooxx.xx
#  2 ooooxxxxx
#  1 o.ooxx.xx
#    ABCDEFGHJ
# W+12.5
# Simulating game 49/100...
#  9 .x.xo.o.o
#  8 xxxxooooo
#  7 xoxooooxx
#  6 xoxxooxxx
#  5 ooxxxxxx.
#  4 o.oxxxxxx
#  3 oooxxooxx
#  2 oooooooox
#  1 o.o.ooxxx
#    ABCDEFGHJ
# W+10.5
# Simulating game 50/100...
#  9 x.xxx.x.x
#  8 xxxxxxxxx
#  7 x.xxxx.x.
#  6 xxx.xxxxx
#  5 .xxxxxxxx
#  4 xxxxxxx.x
#  3 .xxx.xxxx
#  2 xxxxxx.xx
#  1 .xxxxxxx.
#    ABCDEFGHJ
# B+73.5
# Simulating game 51/100...
#  9 o.ooooooo
#  8 ooooo.o.o
#  7 ooo.ooooo
#  6 ooooooo.o
#  5 ooxxo.ooo
#  4 oxxxooooo
#  3 oxoooooxx
#  2 xxxoxoxx.
#  1 x.xxxxxxx
#    ABCDEFGHJ
# W+40.5
# Simulating game 52/100...
#  9 ooooooooo
#  8 .ooooo.oo
#  7 ooo.ooooo
#  6 .oooo.ooo
#  5 ooxxoooo.
#  4 oxxxoo.oo
#  3 x.xxooooo
#  2 xxx.xoooo
#  1 x.xxxoo.o
#    ABCDEFGHJ
# W+50.5
# Simulating game 53/100...
#  9 ooooo.ooo
#  8 o.ooooooo
#  7 oooo.o.oo
#  6 o.ooooooo
#  5 oooooooo.
#  4 o.ooooooo
#  3 ooooo.ooo
#  2 .oooooooo
#  1 ooo.o.o.o
#    ABCDEFGHJ
# W+88.5
# Simulating game 54/100...
#  9 xooooo.oo
#  8 xo.oooooo
#  7 xxoo.ooo.
#  6 xxxoooooo
#  5 x.xxoo.oo
#  4 xxxooooo.
#  3 xxxxxoooo
#  2 xxxxoooo.
#  1 x.xxxxooo
#    ABCDEFGHJ
# W+30.5
# Simulating game 55/100...
#  9 x.xxxxx.x
#  8 xxxxx.xxx
#  7 xxx.xxxxx
#  6 xxxxxoooo
#  5 .xxoooooo
#  4 xxoo.oo.o
#  3 xxooooooo
#  2 xxxoo.ooo
#  1 .xxxooooo
#    ABCDEFGHJ
# B+3.5
# Simulating game 56/100...
#  9 .xxxxxxx.
#  8 xxx.xxxxx
#  7 .xxxx.xxx
#  6 xx.xxxxxx
#  5 xxxxxxxxx
#  4 xxxx.x.x.
#  3 xxxxxxxxx
#  2 xxx.xxxxx
#  1 xxxxx.xxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 57/100...
#  9 xxxxxxx.x
#  8 oxx.x.xxx
#  7 ooxxxxxx.
#  6 ooxxxooxx
#  5 .oxxoooox
#  4 ooooo.ooo
#  3 o.ooooooo
#  2 oooooo.oo
#  1 ooo.ooooo
#    ABCDEFGHJ
# W+24.5
# Simulating game 58/100...
#  9 ooooo.o.o
#  8 o.ooooooo
#  7 oooooooo.
#  6 oooo.oooo
#  5 xxxoooooo
#  4 xxxxxo.oo
#  3 x.xxxoo.o
#  2 xxx.xoooo
#  1 xxxxxo.o.
#    ABCDEFGHJ
# W+42.5
# Simulating game 59/100...
#  9 ooooo.ooo
#  8 ooo.oooox
#  7 ooooo.oxx
#  6 o.ooooxxx
#  5 ooxxxxxxx
#  4 oox.xxx.x
#  3 .oxxxxxxx
#  2 oooooxxx.
#  1 ooooxxxxx
#    ABCDEFGHJ
# W+16.5
# Simulating game 60/100...
#  9 o.oo.ooox
#  8 oooooooxx
#  7 o.oooxxxx
#  6 oooooxxxx
#  5 xxoox.x.x
#  4 xxxxxxxxx
#  3 xxxxxxxoo
#  2 .xxxoooo.
#  1 xxxxoo.oo
#    ABCDEFGHJ
# W+4.5
# Simulating game 61/100...
#  9 xxxxxxxxx
#  8 xox.xx.xx
#  7 oooxxxxx.
#  6 ooxxxx.xx
#  5 .ooooxxxx
#  4 oooxxxxxx
#  3 o.ooxx.xx
#  2 oo.oxxxxx
#  1 .oooxxxxx
#    ABCDEFGHJ
# B+21.5
# Simulating game 62/100...
#  9 .ooooooxx
#  8 oooxoooxx
#  7 .oxxooox.
#  6 oooxooxxx
#  5 .oxxoxxx.
#  4 ooxxxxxxx
#  3 xxxxx.x.x
#  2 xxxxxxxxx
#  1 .xx.xxxx.
#    ABCDEFGHJ
# B+17.5
# Simulating game 63/100...
#  9 ooooo.ooo
#  8 ooxoooo.o
#  7 oxxxxo.oo
#  6 xxxxoooo.
#  5 xxxxxoooo
#  4 .xxxooo.o
#  3 xx.xxoooo
#  2 xxxxxoo.o
#  1 .xx.xoooo
#    ABCDEFGHJ
# W+22.5
# Simulating game 64/100...
#  9 xxooooooo
#  8 .xoxooooo
#  7 xxxxo.o.o
#  6 xx.xooooo
#  5 xxxxoo.oo
#  4 xxxxooooo
#  3 .xx.xooxo
#  2 xxxxxooxx
#  1 x.xxxxxxx
#    ABCDEFGHJ
# W+2.5
# Simulating game 65/100...
#  9 .oo.oooo.
#  8 ooooooooo
#  7 ooo.oo.oo
#  6 .ooo.ooo.
#  5 ooooooooo
#  4 o.o.oo.oo
#  3 ooooooooo
#  2 ooooooooo
#  1 .ooo.oo.o
#    ABCDEFGHJ
# W+88.5
# Simulating game 66/100...
#  9 x.xxxxxxx
#  8 xxxxxxxxx
#  7 .xx.x.xx.
#  6 xxxxxxxxx
#  5 .xxxxx.x.
#  4 xx.xxxxxx
#  3 xxxxxxxxx
#  2 xx.xx.xxx
#  1 xxxxxxxx.
#    ABCDEFGHJ
# B+73.5
# Simulating game 67/100...
#  9 oooo.oooo
#  8 .oooooooo
#  7 oo.ooooo.
#  6 oooooo.oo
#  5 oxoo.oooo
#  4 xxxoooooo
#  3 xxxxoooxx
#  2 xxx.xoxx.
#  1 .xxxxxxxx
#    ABCDEFGHJ
# W+34.5
# Simulating game 68/100...
#  9 .oooooooo
#  8 ooo.ooo.o
#  7 oo.ooo.oo
#  6 ooooooooo
#  5 o.ooo.ooo
#  4 ooooooooo
#  3 oooxxxoxx
#  2 oxxxxxxx.
#  1 xxxx.xxxx
#    ABCDEFGHJ
# W+44.5
# Simulating game 69/100...
#  9 xxxxxoooo
#  8 .xxxoo.o.
#  7 xxxxooooo
#  6 xxx.xxxxx
#  5 x.xxxxxox
#  4 xxxxxoooo
#  3 xxx.xoo.o
#  2 x.xxo.ooo
#  1 xxxoooooo
#    ABCDEFGHJ
# B+5.5
# Simulating game 70/100...
#  9 o.oxxx.x.
#  8 ooox.xxxx
#  7 oooxxxxxx
#  6 .oox.xxxx
#  5 ooooxxxx.
#  4 oxxxxxxxx
#  3 ox.xxx.x.
#  2 xxxxxxxxx
#  1 xxxxxx.xx
#    ABCDEFGHJ
# B+37.5
# Simulating game 71/100...
#  9 x.xxxxxx.
#  8 xxxx.xxxx
#  7 xxxxxxx.x
#  6 .x.xxxxxx
#  5 xxxxx.xx.
#  4 .xxx.xxxx
#  3 xxxxxxxxx
#  2 .x.x.x.xx
#  1 xxxxxxxxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 72/100...
#  9 .xxxx.xx.
#  8 xxx.xxxxx
#  7 .xxxxxxxx
#  6 xxxxx.xxx
#  5 xooxxxxxx
#  4 xxoxxxx.x
#  3 ooooooxxx
#  2 o.ooooooo
#  1 oooo.oo.o
#    ABCDEFGHJ
# B+19.5
# Simulating game 73/100...
#  9 x.xxxxxxx
#  8 xxxxx.xxx
#  7 xx.xxxx.x
#  6 xxxxxxxxx
#  5 xxxx.xxxx
#  4 x.xxxxxxx
#  3 xxxxxxx.x
#  2 xxxxxxxxx
#  1 .xxx.xxxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 74/100...
#  9 xxxxxxxxx
#  8 .xxxx.xxo
#  7 xxxxxxxoo
#  6 xx.xxxooo
#  5 xxxxoxxoo
#  4 x.xxoooo.
#  3 xxxxxo.oo
#  2 oxxxxxoo.
#  1 ooooooooo
#    ABCDEFGHJ
# B+11.5
# Simulating game 75/100...
#  9 x.xxx.xxx
#  8 xxxxxxxxx
#  7 .xxooxxxx
#  6 xxooooox.
#  5 xoo.oooxx
#  4 xooooxx.x
#  3 xooooxxxx
#  2 oo.oxxxxx
#  1 ooooxxx.x
#    ABCDEFGHJ
# B+15.5
# Simulating game 76/100...
#  9 xx.xxoooo
#  8 xxxxooooo
#  7 xx.xoooo.
#  6 xxxxxo.oo
#  5 xxxxxxooo
#  4 .xxx.xooo
#  3 xx.xxxoo.
#  2 xxxoxoooo
#  1 .xxoooo.o
#    ABCDEFGHJ
# W+2.5
# Simulating game 77/100...
#  9 oooooooo.
#  8 oo.o.o.oo
#  7 o.oooooo.
#  6 ooooooooo
#  5 ooo.ooooo
#  4 oooo.ooo.
#  3 .oooooooo
#  2 ooo.ooo.o
#  1 o.ooo.ooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 78/100...
#  9 xooooo.oo
#  8 xoxoxooo.
#  7 xxxoxoxoo
#  6 xxxoxxxo.
#  5 xxxxxoooo
#  4 x.xxxxxoo
#  3 xxxx.xo.o
#  2 xooxxxooo
#  1 xoooooo.o
#    ABCDEFGHJ
# W+12.5
# Simulating game 79/100...
#  9 xx.xx.xxo
#  8 xxxxxxxxo
#  7 xxxxxxoxo
#  6 oxooxxooo
#  5 ooooooo.o
#  4 .oo.ooooo
#  3 oooooo.oo
#  2 .o.oooooo
#  1 oooo.o.o.
#    ABCDEFGHJ
# W+36.5
# Simulating game 80/100...
#  9 x.xx.xxx.
#  8 xxxxxx.xx
#  7 xx.xxxxxx
#  6 oxxxxxxxx
#  5 ooxx.x.xx
#  4 .ooxxxx.x
#  3 ooooxxxxx
#  2 .o.ox.xx.
#  1 ooooxxxxx
#    ABCDEFGHJ
# B+37.5
# Simulating game 81/100...
#  9 ooooooooo
#  8 o.oo.oo.o
#  7 ooooooooo
#  6 oxo.ooo.o
#  5 xxooooooo
#  4 .xoxoo.o.
#  3 xxxxxxooo
#  2 .xx.xxxxx
#  1 xxxxxxxxx
#    ABCDEFGHJ
# W+28.5
# Simulating game 82/100...
#  9 xxxxxxxxx
#  8 xx.xxxx.x
#  7 xxxx.x.xx
#  6 xx.xxxxxx
#  5 xxx.xxx.x
#  4 .xxxxxxxx
#  3 xx.x.xxx.
#  2 xxxxxxxxx
#  1 .x.xxxxx.
#    ABCDEFGHJ
# B+73.5
# Simulating game 83/100...
#  9 xxxoooo.o
#  8 x.xoo.ooo
#  7 xxxooo.o.
#  6 x.xoooooo
#  5 xxooo.ooo
#  4 ooooooooo
#  3 ooo.o.o.o
#  2 ooooooooo
#  1 o.ooo.oo.
#    ABCDEFGHJ
# W+60.5
# Simulating game 84/100...
#  9 .xxxxx.xx
#  8 xxxxxxxxx
#  7 xxxxxx.xx
#  6 x.x.xoxxx
#  5 xxxxxooxx
#  4 oxoxxxoox
#  3 oooxxoooo
#  2 ooooooooo
#  1 o.o.o.oo.
#    ABCDEFGHJ
# B+9.5
# Simulating game 85/100...
#  9 .xxx.xxxx
#  8 xxxxxx.xx
#  7 xxxxxxxxx
#  6 .xxxx.xxx
#  5 xx.xxxxxx
#  4 xxxx.xx.x
#  3 x.xxxxxxx
#  2 xxxx.xxxx
#  1 .xxxxxxxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 86/100...
#  9 ooooox.xx
#  8 o.oooxxx.
#  7 oooooxxxx
#  6 ooooooxoo
#  5 o.oo.ooo.
#  4 ooooooooo
#  3 o.oo.ooo.
#  2 ooooooooo
#  1 .ooo.ooo.
#    ABCDEFGHJ
# W+62.5
# Simulating game 87/100...
#  9 .ox.xxxxx
#  8 ooxxxxx.x
#  7 .oooxxxxx
#  6 ooo.oooxx
#  5 .ooooxxxx
#  4 ooxoxx.x.
#  3 ooxooxxxx
#  2 ooxxxxxxx
#  1 .ooxx.x.x
#    ABCDEFGHJ
# B+9.5
# Simulating game 88/100...
#  9 xxxxxx.x.
#  8 xxxx.xxxx
#  7 x.xxxxxxx
#  6 xxxx.xxxx
#  5 xxxxx.xx.
#  4 xxx.xxxxx
#  3 xxxxxx.x.
#  2 .x.xxxxxx
#  1 xxxx.x.x.
#    ABCDEFGHJ
# B+73.5
# Simulating game 89/100...
#  9 ooooxx.x.
#  8 o.o.oxxxx
#  7 ooooooxx.
#  6 ooooooxxx
#  5 .o.ooooox
#  4 ooooooxxx
#  3 o.oooooxx
#  2 ooo.o.oxo
#  1 ooooooooo
#    ABCDEFGHJ
# W+44.5
# Simulating game 90/100...
#  9 x.xxo.ooo
#  8 xxxxooooo
#  7 .x.xooo.o
#  6 xxxxooooo
#  5 xoooooooo
#  4 xxoxxxooo
#  3 xxxx.xxxo
#  2 x.xxxxx.x
#  1 xxxxx.xxx
#    ABCDEFGHJ
# B+7.5
# Simulating game 91/100...
#  9 .oooooooo
#  8 oooo.oooo
#  7 oo.oooo.o
#  6 ooo.ooooo
#  5 oooooooo.
#  4 .o.ooo.oo
#  3 oooooooo.
#  2 oo.oo.ooo
#  1 .oooooooo
#    ABCDEFGHJ
# W+88.5
# Simulating game 92/100...
#  9 .o.ooooxx
#  8 oooooxxx.
#  7 ooooooxxx
#  6 oo.ooooxx
#  5 oooooxox.
#  4 xxooxxoxx
#  3 .xxoxxxxx
#  2 xxoooxxxx
#  1 .xxxxx.xx
#    ABCDEFGHJ
# W+2.5
# Simulating game 93/100...
#  9 xx.xxxoo.
#  8 xxxx.xxoo
#  7 xxoxxxxoo
#  6 ooooxoooo
#  5 .ooxxoxo.
#  4 oo.oxxxoo
#  3 ooooooooo
#  2 oooooo.o.
#  1 .o.oooooo
#    ABCDEFGHJ
# W+36.5
# Simulating game 94/100...
#  9 xxxx.xxxx
#  8 oooxxxx.x
#  7 .oooooxxx
#  6 ooooooxxx
#  5 .o.o.ooox
#  4 oooooooxx
#  3 xoooxxoxx
#  2 xxxox.xx.
#  1 xxxxxxxxx
#    ABCDEFGHJ
# B+3.5
# Simulating game 95/100...
#  9 o.ooooooo
#  8 oooo.oo.o
#  7 ooooooooo
#  6 xoooooooo
#  5 xxxxxxxxx
#  4 oooxoxxxx
#  3 .oooox.xx
#  2 oo.ooxxxx
#  1 .oooxx.xx
#    ABCDEFGHJ
# W+32.5
# Simulating game 96/100...
#  9 x.xxx.xxx
#  8 xxx.xxxxx
#  7 xxxxxx.x.
#  6 xx.x.xxxx
#  5 ooxxxxxxx
#  4 .oooxxoxx
#  3 oo.oooooo
#  2 oooo.oooo
#  1 .o.ooooo.
#    ABCDEFGHJ
# B+5.5
# Simulating game 97/100...
#  9 xx.xx.xxx
#  8 xxxxxxxxx
#  7 xxx.xxxx.
#  6 x.xxxxxxx
#  5 xxxxxxx.x
#  4 x.x.xxxxx
#  3 xxxxxxx.x
#  2 xxxxxxxxx
#  1 xx.xxxxxx
#    ABCDEFGHJ
# B+73.5
# Simulating game 98/100...
#  9 oo.ox.x.x
#  8 .oooxxxxx
#  7 oooxxxxxx
#  6 ooxxxxxxx
#  5 .oxx.x.xx
#  4 ooxxxxxxx
#  3 oxx.xxxx.
#  2 xx.xxxxxx
#  1 .xxxxx.x.
#    ABCDEFGHJ
# B+37.5
# Simulating game 99/100...
#  9 .ooo.oooo
#  8 ooooooooo
#  7 ooooooo.o
#  6 oooooo.oo
#  5 .ooxxoooo
#  4 ooxx.xooo
#  3 oxxxxxxoo
#  2 ooxxxxxxx
#  1 xxxxx.xx.
#    ABCDEFGHJ
# W+32.5
# Simulating game 100/100...
#  9 xxxxxxxxx
#  8 x.xxx.xxx
#  7 xxxxxxxxx
#  6 xoooxxx.x
#  5 oooxxoxxx
#  4 ooooxooox
#  3 .oo.oooxx
#  2 ooooo.oxx
#  1 o.oooooxx
#    ABCDEFGHJ
# B+3.5
# simulatinon of 100 games , cost_time:24.825s.
# collect 11494 samples

# %% [markdown]
# ## playground

# %%
# 测试gpu数据和模型 序列化和反序列化的应用
import os
import torch
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# device = torch.device('cpu')
print("device:", device)
# Out:
# device: cuda

# %%
# save to disk
model = torch.nn.Linear(12,1).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

x = torch.randn((1,3,4), dtype=torch.float32).to(device)
y = model(torch.nn.Flatten(start_dim=1)(x))
print(y)

y1 = torch.LongTensor(1)
y2 = 2233
y3 = np.array([1,2,3])

print(y3, type(y3))

checkpoint = {
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'epoch': 100,  # 保存当前训练的轮次
    'x': x,
    'y1': y1,
    'y2': y2,
    'y3': y3,
}

pth = "data/checkpoint/test_pth.pth"
if not os.path.exists('data/checkpoint/'):
    os.makedirs('data/checkpoint/')
torch.save(checkpoint, pth)
# Out:
# tensor([[-0.4894]], device='cuda:0', grad_fn=<AddmmBackward0>)
# [1 2 3] <class 'numpy.ndarray'>

# %%
# load from disk

# 创建模型实例（必须与保存时的模型结构一致）
model = torch.nn.Linear(12,1).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)
checkpoint = torch.load(pth)

x = checkpoint['x']
print(x)

y_new = model(torch.nn.Flatten(start_dim=1)(x))
print(y_new)

# laod model
model.load_state_dict(checkpoint['model_state_dict'])
y_old = model(torch.nn.Flatten(start_dim=1)(x))
print(y_old)

epoch = checkpoint['epoch']
print(checkpoint['epoch'])

y3 = checkpoint['y3']
print(y3, type(y3))

# optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# model.train()  # 或 model.eval()
# 结果显示，可以直接存储cuda格式的数据, np格式的序列化也统统没有问题
# Out:
# tensor([[[ 0.5703,  1.0359,  0.4338,  0.7824],
#          [-0.5979,  0.6990, -1.4519,  1.9334],
#          [-2.0659, -0.0798, -1.8046,  0.2827]]], device='cuda:0')
# tensor([[-0.3260]], device='cuda:0', grad_fn=<AddmmBackward0>)
# tensor([[-0.4894]], device='cuda:0', grad_fn=<AddmmBackward0>)
# 100
# [1 2 3] <class 'numpy.ndarray'>
